# %% [markdown]
# # Testing queries OpenSearch

# %%
# %cd ..
from opensearchpy import OpenSearch, helpers
import pandas as pd
from pprint import pp
from dotenv import load_dotenv
from tqdm import tqdm
import os
def ppr(resp):
    pp(resp.raw)
import time
# Out:
# c:\
# c:\ulb\SearchEngines_benchmark\venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ### Connecting to database

# %%
load_dotenv()

# Recupera la variabile della password dall'ambiente
OPENSEARCH_INITIAL_ADMIN_PASSWORD = os.getenv("OPENSEARCH_INITIAL_ADMIN_PASSWORD")
OPENSEARCH_URL = os.getenv("OPENSEARCH_URL")  # Ad esempio http://localhost:9200

# Verifica che la password sia stata caricata correttamente
if OPENSEARCH_INITIAL_ADMIN_PASSWORD:
    print("Password caricata con successo.")
else:
    print("Errore nel caricare la password.")
# Out:
# Password caricata con successo.

# %%
client = OpenSearch(
    hosts=[OPENSEARCH_URL],
    http_auth=("admin", OPENSEARCH_INITIAL_ADMIN_PASSWORD),
    use_ssl=False,
    verify_certs=False,
    ssl_assert_hostname=False,
    ssl_show_warn=False
)
try:
    info = client.info()
    print("Conection to OpenSearch succeded!")
except Exception as e:
    print(f"Error when connecting: {e}")
# Out:
# Conection to OpenSearch succeded!

# %% [markdown]
# ## Queries

# %%
# Initialize empty dataframe
df_results = pd.DataFrame(columns=['query_id', 'execution_time','run'])

# %% [markdown]
# Query that counts how many times are mentioned this programming languages on the posts (Sql, python, R, Java, JavaScript, C++, Ruby, PHP)

# %% [markdown]
# ### Post data

# %%
counter = 0
while counter < 11:
    # Measure execution time
    start_time = time.time()
    # Query that counts how many times are mentioned this programming languages on the posts (Sql, python, R, Java, JavaScript, C++, Ruby, PHP)
    query1 = client.search(
        index='posts_analyzed_v2',
        body={
            "size": 0,  # We're aggregating, not fetching individual documents
            "query": {
                "bool": {
                    "should": [
                        {"match_phrase": {"Body": "sql"}},
                        {"match_phrase": {"Body": "python"}},
                        {"match_phrase": {"Body": " R "}},
                        {"match_phrase": {"Body": "java"}},
                        {"match_phrase": {"Body": "javascript"}},
                        {"match_phrase": {"Body": "c++"}},
                        {"match_phrase": {"Body": "ruby"}},
                        {"match_phrase": {"Body": "php"}}
                    ]
                }
            },
            "aggs": {
                "Programming_Language": {
                    "filters": {
                        "filters": {
                            "SQL": {"match_phrase": {"Body": "sql"}},
                            "Python": {"match_phrase": {"Body": "python"}},
                            "R": {"match_phrase": {"Body": " R "}},
                            "Java": {"match_phrase": {"Body": "java"}},
                            "JavaScript": {"match_phrase": {"Body": "javascript"}},
                            "C++": {"match_phrase": {"Body": "c++"}},
                            "Ruby": {"match_phrase": {"Body": "ruby"}},
                            "PHP": {"match_phrase": {"Body": "php"}}
                        }
                    }
                }
            }
        }
    )
    execution_time = time.time() - start_time


    # Save results in a pandas DataFrame
    data = {
        "query_id": 1,
        "execution_time": [execution_time],
        "run":counter
    }

    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])

    counter+=1 # update counter

# Print the DataFrame
print(df_results)
# Out:
# C:\Users\jidsc\AppData\Local\Temp\ipykernel_36256\1439651481.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_results=pd.concat([df_results, df])
#   query_id  execution_time run
# 0        1        0.078320   0
# 0        1        0.052797   1
# 0        1        0.053349   2
# 0        1        0.064269   3
# 0        1        0.049232   4
# 0        1        0.049395   5
# 0        1        0.049204   6
# 0        1        0.057044   7
# 0        1        0.051578   8
# 0        1        0.049070   9
# 0        1        0.046629  10

# %% [markdown]
# ### Comments data

# %%
counter = 0
while counter < 11:
    # Measure execution time
    start_time = time.time()
    # Query that counts how many times are mentioned this programming languages on the posts (Sql, python, R, Java, JavaScript, C++, Ruby, PHP)
    query1 = client.search(
        index='comments',
        body={
            "size": 0,  # We're aggregating, not fetching individual documents
            "query": {
                "bool": {
                    "should": [
                        {"match_phrase": {"Text": "sql"}},
                        {"match_phrase": {"Text": "python"}},
                        {"match_phrase": {"Text": " R "}},
                        {"match_phrase": {"Text": "java"}},
                        {"match_phrase": {"Text": "javascript"}},
                        {"match_phrase": {"Text": "c++"}},
                        {"match_phrase": {"Text": "ruby"}},
                        {"match_phrase": {"Text": "php"}}
                    ]
                }
            },
            "aggs": {
                "Programming_Language": {
                    "filters": {
                        "filters": {
                            "SQL": {"match_phrase": {"Text": "sql"}},
                            "Python": {"match_phrase": {"Text": "python"}},
                            "R": {"match_phrase": {"Text": " R "}},
                            "Java": {"match_phrase": {"Text": "java"}},
                            "JavaScript": {"match_phrase": {"Text": "javascript"}},
                            "C++": {"match_phrase": {"Text": "c++"}},
                            "Ruby": {"match_phrase": {"Text": "ruby"}},
                            "PHP": {"match_phrase": {"Text": "php"}}
                        }
                    }
                }
            }
        }
    )
    execution_time = time.time() - start_time


    # Save results in a pandas DataFrame
    data = {
        "query_id": 2,
        "execution_time": [execution_time],
        "run":counter
    }

    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])
    counter+=1 # update counter

# Print the DataFrame
print(df_results)
# Out:
#   query_id  execution_time run
# 0        1        0.078320   0
# 0        1        0.052797   1
# 0        1        0.053349   2
# 0        1        0.064269   3
# 0        1        0.049232   4
# 0        1        0.049395   5
# 0        1        0.049204   6
# 0        1        0.057044   7
# 0        1        0.051578   8
# 0        1        0.049070   9
# 0        1        0.046629  10
# 0        2        0.056187   0
# 0        2        0.050157   1
# 0        2        0.049587   2
# 0        2        0.049404   3
# 0        2        0.049414   4
# 0        2        0.049122   5
# 0        2        0.059278   6
# 0        2        0.059716   7
# 0        2        0.049005   8
# 0        2        0.049756   9
# 0        2        0.048389  10

# %% [markdown]
# ### Post data

# %% [markdown]
# Query that counts how many times are mentioned this programming languages on the posts (Sql, python, R, Java, JavaScript, C++, Ruby, PHP) by user

# %%
counter = 0
while counter < 11:
    # Query that counts how many times are mentioned this programming languages on the posts (Sql, python, R, Java, JavaScript, C++, Ruby, PHP) by user
    all_buckets = []
    after_key = None  # Pagination key starts as None
    # Measure execution time
    start_time = time.time()
    while True:
        # Build the query
        body = {
            "size": 0,  # No document hits, just aggregations
            "query": {
                "bool": {
                    "should": [
                        {"match": {"Body": "sql"}},
                        {"match": {"Body": "python"}},
                        {"match": {"Body": " R "}},
                        {"match": {"Body": "java"}},
                        {"match": {"Body": "javascript"}},
                        {"match": {"Body": "c++"}},
                        {"match": {"Body": "ruby"}},
                        {"match": {"Body": "php"}}
                    ]
                }
            },
            "aggs": {
                "OwnerUserId": {
                    "composite": {
                        "sources": [
                            {"OwnerUserId": {"terms": {"field": "OwnerUserId"}}}
                        ],
                        "size": 5000  # Fetch 1000 buckets per page
                    },
                    "aggs": {
                        "Programming_Language": {
                            "filters": {
                                "filters": {
                                    "SQL": {"match": {"Body": "sql"}},
                                    "Python": {"match": {"Body": "python"}},
                                    "R": {"match": {"Body": " R "}},
                                    "Java": {"match": {"Body": "java"}},
                                    "JavaScript": {"match": {"Body": "javascript"}},
                                    "C++": {"match": {"Body": "c++"}},
                                    "Ruby": {"match": {"Body": "ruby"}},
                                    "PHP": {"match": {"Body": "php"}},
                                    "Other": {
                                        "bool": {
                                            "must_not": [
                                                {"match": {"Body": "sql"}},
                                                {"match": {"Body": "python"}},
                                                {"match": {"Body": " R "}},
                                                {"match": {"Body": "java"}},
                                                {"match": {"Body": "javascript"}},
                                                {"match": {"Body": "c++"}},
                                                {"match": {"Body": "ruby"}},
                                                {"match": {"Body": "php"}}
                                            ]
                                        }
                                    }
                                }
                            },
                            "aggs": {
                                "Post_Count": {
                                    "value_count": {"field": "_id"}
                                }
                            }
                        }
                    }
                }
            }
        }

        # Add the after_key to the composite aggregation if it's set
        if after_key:
            body["aggs"]["OwnerUserId"]["composite"]["after"] = after_key

        # Execute the search

        resp = client.search(index="posts_analyzed_v2", body=body)

        # Extract buckets
        buckets = resp["aggregations"]["OwnerUserId"]["buckets"]
        all_buckets.extend(buckets)

        # Check if there's more data to fetch
        if "after_key" in resp["aggregations"]["OwnerUserId"]:
            after_key = resp["aggregations"]["OwnerUserId"]["after_key"]
        else:
            break

    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time}")

    # Extract number of rows and columns
    # Save results in a pandas DataFrame
    data = {
        "query_id": 3,
        "execution_time": [execution_time],
        "run":counter
    }


    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])
    counter+=1

# Print the DataFrame
print(df_results)
# Out:
# Execution time: 1.3426027297973633
# Execution time: 1.339674711227417
# Execution time: 1.346628189086914
# Execution time: 1.5896525382995605
# Execution time: 1.414564847946167
# Execution time: 3.0566189289093018
# Execution time: 3.278069257736206
# Execution time: 3.4802608489990234
# Execution time: 3.057584524154663
# Execution time: 2.9793596267700195
# Execution time: 2.8654839992523193
#   query_id  execution_time run
# 0        1        0.078320   0
# 0        1        0.052797   1
# 0        1        0.053349   2
# 0        1        0.064269   3
# 0        1        0.049232   4
# 0        1        0.049395   5
# 0        1        0.049204   6
# 0        1        0.057044   7
# 0        1        0.051578   8
# 0        1        0.049070   9
# 0        1        0.046629  10
# 0        2        0.056187   0
# 0        2        0.050157   1
# 0        2        0.049587   2
# 0        2        0.049404   3
# 0        2        0.049414   4
# 0        2        0.049122   5
# 0        2        0.059278   6
# 0        2        0.059716   7
# 0        2        0.049005   8
# 0        2        0.049756   9
# 0        2        0.048389  10
# 0        3        1.342603   0
# 0        3        1.339675   1
# 0        3        1.346628   2
# 0        3        1.589653   3
# 0        3        1.414565   4
# 0        3        3.056619   5
# 0        3        3.278069   6
# 0        3        3.480261   7
# 0        3        3.057585   8
# 0        3        2.979360   9
# 0        3        2.865484  10

# %%
counter = 0
while counter < 11:
    # Query that counts how many times are mentioned this programming languages on the posts (Sql, python, R, Java, JavaScript, C++, Ruby, PHP) by user
    all_buckets = []
    after_key = None  # Pagination key starts as None
    # Measure execution time
    start_time = time.time()
    while True:
        # Build the query
        body = {
            "size": 0,  # No document hits, just aggregations
            "query": {
                "bool": {
                    "should": [
                        {"match": {"Text": "sql"}},
                        {"match": {"Text": "python"}},
                        {"match": {"Text": " R "}},
                        {"match": {"Text": "java"}},
                        {"match": {"Text": "javascript"}},
                        {"match": {"Text": "c++"}},
                        {"match": {"Text": "ruby"}},
                        {"match": {"Text": "php"}}
                    ]
                }
            },
            "aggs": {
                "UserId": {
                    "composite": {
                        "sources": [
                            {"UserId": {"terms": {"field": "UserId"}}}
                        ],
                        "size": 5000  # Fetch 1000 buckets per page
                    },
                    "aggs": {
                        "Programming_Language": {
                            "filters": {
                                "filters": {
                                    "SQL": {"match": {"Text": "sql"}},
                                    "Python": {"match": {"Text": "python"}},
                                    "R": {"match": {"Text": " R "}},
                                    "Java": {"match": {"Text": "java"}},
                                    "JavaScript": {"match": {"Text": "javascript"}},
                                    "C++": {"match": {"Text": "c++"}},
                                    "Ruby": {"match": {"Text": "ruby"}},
                                    "PHP": {"match": {"Text": "php"}},
                                    "Other": {
                                        "bool": {
                                            "must_not": [
                                                {"match": {"Text": "sql"}},
                                                {"match": {"Text": "python"}},
                                                {"match": {"Text": " R "}},
                                                {"match": {"Text": "java"}},
                                                {"match": {"Text": "javascript"}},
                                                {"match": {"Text": "c++"}},
                                                {"match": {"Text": "ruby"}},
                                                {"match": {"Text": "php"}}
                                            ]
                                        }
                                    }
                                }
                            },
                            "aggs": {
                                "Post_Count": {
                                    "value_count": {"field": "_id"}
                                }
                            }
                        }
                    }
                }
            }
        }

        # Add the after_key to the composite aggregation if it's set
        if after_key:
            body["aggs"]["UserId"]["composite"]["after"] = after_key

        # Execute the search

        resp = client.search(index="comments", body=body)

        # Extract buckets
        buckets = resp["aggregations"]["UserId"]["buckets"]
        all_buckets.extend(buckets)

        # Check if there's more data to fetch
        if "after_key" in resp["aggregations"]["UserId"]:
            after_key = resp["aggregations"]["UserId"]["after_key"]
        else:
            break

    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time}")

    # Extract number of rows and columns
    # Save results in a pandas DataFrame
    data = {
        "query_id": 4,
        "execution_time": [execution_time],
        "run":counter
    }

    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])
    counter+=1

# Print the DataFrame
print(df_results)
# Out:
# Execution time: 0.8883001804351807
# Execution time: 1.1290128231048584
# Execution time: 0.7385830879211426
# Execution time: 0.8715713024139404
# Execution time: 0.716524600982666
# Execution time: 0.706453800201416
# Execution time: 0.7413980960845947
# Execution time: 0.7199230194091797
# Execution time: 0.7319691181182861
# Execution time: 0.713829755783081
# Execution time: 0.745642900466919
#   query_id  execution_time run
# 0        1        0.078320   0
# 0        1        0.052797   1
# 0        1        0.053349   2
# 0        1        0.064269   3
# 0        1        0.049232   4
# 0        1        0.049395   5
# 0        1        0.049204   6
# 0        1        0.057044   7
# 0        1        0.051578   8
# 0        1        0.049070   9
# 0        1        0.046629  10
# 0        2        0.056187   0
# 0        2        0.050157   1
# 0        2        0.049587   2
# 0        2        0.049404   3
# 0        2        0.049414   4
# 0        2        0.049122   5
# 0        2        0.059278   6
# 0        2        0.059716   7
# 0        2        0.049005   8
# 0        2        0.049756   9
# 0        2        0.048389  10
# 0        3        1.342603   0
# 0        3        1.339675   1
# 0        3        1.346628   2
# 0        3        1.589653   3
# 0        3        1.414565   4
# 0        3        3.056619   5
# 0        3        3.278069   6
# 0        3        3.480261   7
# 0        3        3.057585   8
# 0        3        2.979360   9
# 0        3        2.865484  10
# 0        4        0.888300   0
# 0        4        1.129013   1
# 0        4        0.738583   2
# 0        4        0.871571   3
# 0        4        0.716525   4
# 0        4        0.706454   5
# 0        4        0.741398   6
# 0        4        0.719923   7
# 0        4        0.731969   8
# 0        4        0.713830   9
# 0        4        0.745643  10

# %% [markdown]
# ## query for counting top 20 words

# %% [markdown]
# Query that counts the Top 20 common words in comments without considering stop words (posts)

# %%
counter = 0
while counter < 11:
    query_body = {
        "size": 0,  # No need to fetch individual documents
        "aggs": {
            "top_words": {
                "terms": {
                    "field": "Body",  # Tokenized text field
                    "size": 20,  # Top 20 most common words
                    "order": {"_count": "desc"}
                }
            }
        }
    }
    # Measure execution time
    start_time = time.time()
    response = client.search(index="posts_analyzed_v2", body=query_body, request_timeout=60)  # Set timeout to 60 seconds
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time}")

    # Parse and display results
    top_words = response['aggregations']['top_words']['buckets']
    for word in top_words:
        print(f"Word: {word['key']}, Count: {word['doc_count']}")

    # Extract number of rows and columns
    # Save results in a pandas DataFrame
    data = {
        "query_id": 5,
        "execution_time": [execution_time],
        "run":counter
    }

    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])

    counter+=1

# Print the DataFrame
print(df_results)
# Out:
# Execution time: 5.186573266983032
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.003323078155517578
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.04938864707946777
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.049855947494506836
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.04854846000671387
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.04928112030029297
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.04955101013183594
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.04957771301269531
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.04868030548095703
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.05409646034240723
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
# Execution time: 0.054633378982543945
# Word: p, Count: 1550119
# Word: you, Count: 847548
# Word: code, Count: 821440
# Word: i, Count: 802987
# Word: pre, Count: 572727
# Word: have, Count: 553127
# Word: can, Count: 551931
# Word: href, Count: 464172
# Word: http, Count: 446999
# Word: use, Count: 441009
# Word: rel, Count: 425134
# Word: noreferrer, Count: 423357
# Word: your, Count: 418125
# Word: do, Count: 413752
# Word: from, Count: 398148
# Word: so, Count: 355685
# Word: like, Count: 352384
# Word: using, Count: 347864
# Word: nofollow, Count: 346530
# Word: what, Count: 307468
#   query_id  execution_time run
# 0        1        0.078320   0
# 0        1        0.052797   1
# 0        1        0.053349   2
# 0        1        0.064269   3
# 0        1        0.049232   4
# 0        1        0.049395   5
# 0        1        0.049204   6
# 0        1        0.057044   7
# 0        1        0.051578   8
# 0        1        0.049070   9
# 0        1        0.046629  10
# 0        2        0.056187   0
# 0        2        0.050157   1
# 0        2        0.049587   2
# 0        2        0.049404   3
# 0        2        0.049414   4
# 0        2        0.049122   5
# 0        2        0.059278   6
# 0        2        0.059716   7
# 0        2        0.049005   8
# 0        2        0.049756   9
# 0        2        0.048389  10
# 0        3        1.342603   0
# 0        3        1.339675   1
# 0        3        1.346628   2
# 0        3        1.589653   3
# 0        3        1.414565   4
# 0        3        3.056619   5
# 0        3        3.278069   6
# 0        3        3.480261   7
# 0        3        3.057585   8
# 0        3        2.979360   9
# 0        3        2.865484  10
# 0        4        0.888300   0
# 0        4        1.129013   1
# 0        4        0.738583   2
# 0        4        0.871571   3
# 0        4        0.716525   4
# 0        4        0.706454   5
# 0        4        0.741398   6
# 0        4        0.719923   7
# 0        4        0.731969   8
# 0        4        0.713830   9
# 0        4        0.745643  10
# 0        5        5.186573   0
# 0        5        0.003323   1
# 0        5        0.049389   2
# 0        5        0.049856   3
# 0        5        0.048548   4
# 0        5        0.049281   5
# 0        5        0.049551   6
# 0        5        0.049578   7
# 0        5        0.048680   8
# 0        5        0.054096   9
# 0        5        0.054633  10

# %%
counter = 0
while counter < 11:
    query_body = {
        "size": 0,  # No need to fetch individual documents
        "aggs": {
            "top_words": {
                "terms": {
                    "field": "Text",  # Tokenized text field
                    "size": 20,  # Top 20 most common words
                    "order": {"_count": "desc"}
                }
            }
        }
    }
    # Measure execution time
    start_time = time.time()
    response = client.search(index="comments", body=query_body, request_timeout=60)  # Set timeout to 60 seconds
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time}")

    # Parse and display results
    top_words = response['aggregations']['top_words']['buckets']
    for word in top_words:
        print(f"Word: {word['key']}, Count: {word['doc_count']}")

    # Extract number of rows and columns
    # Save results in a pandas DataFrame
    data = {
        "query_id": 6,
        "execution_time": [execution_time],
        "run":counter
    }

    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])

    counter+=1

# Print the DataFrame
print(df_results)
# Out:
# Execution time: 0.5329370498657227
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.0031189918518066406
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.04354691505432129
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.04916191101074219
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.049866437911987305
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.048996686935424805
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.04959893226623535
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.04829668998718262
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.05403709411621094
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.052799224853515625
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
# Execution time: 0.05894780158996582
# Word: i, Count: 550277
# Word: you, Count: 441869
# Word: have, Count: 202457
# Word: your, Count: 162849
# Word: can, Count: 158857
# Word: what, Count: 156775
# Word: do, Count: 154288
# Word: my, Count: 142987
# Word: so, Count: 140340
# Word: just, Count: 137719
# Word: thanks, Count: 136731
# Word: use, Count: 121226
# Word: would, Count: 117498
# Word: code, Count: 112307
# Word: it's, Count: 108424
# Word: like, Count: 106031
# Word: from, Count: 100457
# Word: using, Count: 95149
# Word: don't, Count: 94178
# Word: all, Count: 92672
#    query_id  execution_time run
# 0         1        0.078320   0
# 0         1        0.052797   1
# 0         1        0.053349   2
# 0         1        0.064269   3
# 0         1        0.049232   4
# ..      ...             ...  ..
# 0         6        0.049599   6
# 0         6        0.048297   7
# 0         6        0.054037   8
# 0         6        0.052799   9
# 0         6        0.058948  10
#
# [66 rows x 3 columns]

# %%
counter = 0
while counter < 11:
    query_body = {
        "size": 0,  # No need to retrieve individual documents
        "aggs": {
            "post_counts": {
                "terms": {
                    "field": "OwnerUserId",  # Group by OwnerUserId
                    "size": 10,  # Top 10
                    "order": {"_count": "desc"}  # Order by count descending
                }
            }
        }
    }
    # Measure execution time
    start_time = time.time()
    response = client.search(index="posts_analyzed_v2", body=query_body)
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time}")

    # Parse and display results
    if "aggregations" in response:
        for bucket in response["aggregations"]["post_counts"]["buckets"]:
            print(f"OwnerUserId: {bucket['key']}, Post_Count: {bucket['doc_count']}")
    else:
        print("No aggregations found in the response.")


    # Extract number of rows and columns
    # Save results in a pandas DataFrame
    data = {
        "query_id": 7,
        "execution_time": [execution_time],
        "run":counter
    }

    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])
    
    counter+=1

# Print the DataFrame
print(df_results)
# Out:
# Execution time: 0.15579724311828613
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.0029184818267822266
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.05881786346435547
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.052518606185913086
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.04885077476501465
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.04513120651245117
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.04878592491149902
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.048897504806518555
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.048178911209106445
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.04951024055480957
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
# Execution time: 0.049222707748413086
# OwnerUserId: 0, Post_Count: 76662
# OwnerUserId: 22656, Post_Count: 6428
# OwnerUserId: 23354, Post_Count: 4624
# OwnerUserId: 12950, Post_Count: 3227
# OwnerUserId: 95810, Post_Count: 2800
# OwnerUserId: 3043, Post_Count: 2677
# OwnerUserId: 23283, Post_Count: 2598
# OwnerUserId: 76337, Post_Count: 2281
# OwnerUserId: 10661, Post_Count: 2137
# OwnerUserId: 18393, Post_Count: 2094
#    query_id  execution_time run
# 0         1        0.078320   0
# 0         1        0.052797   1
# 0         1        0.053349   2
# 0         1        0.064269   3
# 0         1        0.049232   4
# ..      ...             ...  ..
# 0         7        0.048786   6
# 0         7        0.048898   7
# 0         7        0.048179   8
# 0         7        0.049510   9
# 0         7        0.049223  10
#
# [77 rows x 3 columns]

# %%
counter = 0
while counter < 11:
    query_body = {
        "size": 0,  # No need to retrieve individual documents
        "aggs": {
            "comments_counts": {
                "terms": {
                    "field": "UserId",  # Group by OwnerUserId
                    "size": 10,  # Top 10
                    "order": {"_count": "desc"}  # Order by count descending
                }
            }
        }
    }
    # Measure execution time
    start_time = time.time()
    response = client.search(index="comments", body=query_body)
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time}")

    # Parse and display results
    if "aggregations" in response:
        for bucket in response["aggregations"]["comments_counts"]["buckets"]:
            print(f"UserId: {bucket['key']}, Comments_counts: {bucket['doc_count']}")
    else:
        print("No aggregations found in the response.")


    # Extract number of rows and columns
    # Save results in a pandas DataFrame
    data = {
        "query_id": 8,
        "execution_time": [execution_time],
        "run":counter
    }

    df = pd.DataFrame(data)

    df_results=pd.concat([df_results, df])
    counter +=1

# Print the DataFrame
print(df_results)
# Out:
# Execution time: 0.12177228927612305
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.002836942672729492
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.04894399642944336
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.049497127532958984
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.05351376533508301
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.057071685791015625
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.05772709846496582
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.06658768653869629
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.05662250518798828
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.05522298812866211
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
# Execution time: 0.049105167388916016
# UserId: -1, Comments_counts: 41626
# UserId: 22656, Comments_counts: 7553
# UserId: 23354, Comments_counts: 4996
# UserId: 10661, Comments_counts: 4670
# UserId: 76337, Comments_counts: 4511
# UserId: 34509, Comments_counts: 3666
# UserId: 15168, Comments_counts: 3375
# UserId: 14860, Comments_counts: 2840
# UserId: 3043, Comments_counts: 2829
# UserId: 13005, Comments_counts: 2751
#    query_id  execution_time run
# 0         1        0.078320   0
# 0         1        0.052797   1
# 0         1        0.053349   2
# 0         1        0.064269   3
# 0         1        0.049232   4
# ..      ...             ...  ..
# 0         8        0.057727   6
# 0         8        0.066588   7
# 0         8        0.056623   8
# 0         8        0.055223   9
# 0         8        0.049105  10
#
# [88 rows x 3 columns]

# %% [markdown]
# # Results

# %%
df_results = df_results[~(df_results['run']==0)]

# %%
df_results.groupby('query_id').agg({'execution_time':'mean'}).reset_index()
# Out:
#    query_id  execution_time
# 0         1        0.052257
# 1         2        0.051383
# 2         3        2.440790
# 3         4        0.781491
# 4         5        0.045694
# 5         6        0.045837
# 6         7        0.045283
# 7         8        0.049713
